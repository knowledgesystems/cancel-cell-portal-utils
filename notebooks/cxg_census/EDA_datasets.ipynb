# %%
import cellxgene_census

census = cellxgene_census.open_soma()
# Out:
# The "stable" release is currently 2025-01-30. Specify 'census_version="2025-01-30"' in future calls to open_soma() to ensure data consistency.

# %%
eda_ds = census["census_info"]["datasets"]
eda_ds.read().concat().to_pandas()
# Out:
#       soma_joinid                                           citation  \
# 0               0  Publication: https://doi.org/10.1016/j.isci.20...
# 1               1  Publication: https://doi.org/10.1016/j.isci.20...
# 2               2  Publication: https://doi.org/10.1016/j.isci.20...
# 3               3  Publication: https://doi.org/10.1016/j.isci.20...
# 4               4  Publication: https://doi.org/10.1038/s41591-02...
# ...           ...                                                ...
# 1568         1568  Publication: https://doi.org/10.1038/s41586-02...
# 1569         1569  Publication: https://doi.org/10.1126/science.a...
# 1570         1570  Publication: https://doi.org/10.1038/s41586-02...
# 1571         1571  Publication: https://doi.org/10.1038/s41593-02...
# 1572         1572  Publication: https://doi.org/10.1038/s41593-02...
#
#                              collection_id  \
# 0     8e880741-bf9a-4c8e-9227-934204631d2a
# 1     8e880741-bf9a-4c8e-9227-934204631d2a
# ...

# %%
census_datasets = (
    census["census_info"]["datasets"]
    # .read(column_names=["collection_name", "dataset_title", "dataset_id", "soma_joinid"])
    .read()
    .concat()
    .to_pandas()
)
census_datasets = census_datasets.set_index("dataset_id")
census_datasets
# Out:
#                                       soma_joinid  \
# dataset_id
# 4eb29386-de81-452f-b3c0-e00844e8c7fd            0
# 78d59e4a-82eb-4a61-a1dc-da974d7ea54b            1
# add5eb84-5fc9-4f01-982e-a346dd42ee82            2
# b020294c-ab82-4547-b5a7-63d8ffa575ed            3
# d7476ae2-e320-4703-8304-da5c42627e71            4
# ...                                           ...
# dcfa2614-7ca7-4d82-814c-350626eccb26         1568
# 53d208b0-2cfd-4366-9866-c3c6114081bc         1569
# dcfd4feb-18a3-4b30-81d7-1b0c544a8ab3         1570
# c2876b1b-06d8-4d96-a56b-5304f815b99a         1571
# 6f7fd0f1-a2ed-4ff1-80d3-33dde731cbc3         1572
#
#                                                                                citation  \
# dataset_id
# 4eb29386-de81-452f-b3c0-e00844e8c7fd  Publication: https://doi.org/10.1016/j.isci.20...
# 78d59e4a-82eb-4a61-a1dc-da974d7ea54b  Publication: https://doi.org/10.1016/j.isci.20...
# ...
